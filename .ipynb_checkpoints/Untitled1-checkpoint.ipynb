# %%
from scripts.spark_session import spark
spark.sparkContext.setLogLevel("ERROR")

# %%
url1 = 'jdbc:mysql://localhost:3306/bronze'

# %%
connect_properties = {
    'user' : 'root', 
    'password': 'macintosh',
    'driver': 'com.mysql.cj.jdbc.Driver'
}

# %%
bronze_df = spark.read.jdbc(properties=connect_properties, url=url1, table='b_transaction')
bronze_df.show(3)
# Out:
# ---------------------------------------------------------------------------
# AnalysisException                         Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 bronze_df = spark.read.jdbc(properties=connect_properties, url=url1, table='b_transaction')
#       2 bronze_df.show(3)
#
# File ~/thisWorks/myvenv/lib/python3.14/site-packages/pyspark/sql/readwriter.py:1274, in DataFrameReader.jdbc(self, url, table, column, lowerBound, upperBound, numPartitions, predicates, properties)
#    1270     jpredicates = utils.to_java_array(
#    1271         gateway, getattr(gateway.jvm, "java.lang.String"), predicates
#    1272     )
#    1273     return self._df(self._jreader.jdbc(url, table, jpredicates, jprop))
# -> 1274 return self._df(self._jreader.jdbc(url, table, jprop))
#
# File ~/thisWorks/myvenv/lib/python3.14/site-packages/py4j/java_gateway.py:1362, in JavaMember.__call__(self, *args)
#    1356 command = proto.CALL_COMMAND_NAME +\
#    1357     self.command_header +\
#    1358     args_command +\
#    1359     proto.END_COMMAND_PART
#    1361 answer = self.gateway_client.send_command(command)
# -> 1362 return_value = get_return_value(
#    1363     answer, self.gateway_client, self.target_id, self.name)
#    1365 for temp_arg in temp_args:
#    1366     if hasattr(temp_arg, "_detach"):
#
# File ~/thisWorks/myvenv/lib/python3.14/site-packages/pyspark/errors/exceptions/captured.py:257, in capture_sql_exception.<locals>.deco(*a, **kw)
#     253 converted = convert_exception(e.java_exception)
#     254 if not isinstance(converted, UnknownException):
#     255     # Hide where the exception came from that shows a non-Pythonic
#     256     # JVM exception message.
# --> 257     raise converted from None
#     258 else:
#     259     raise
#
# AnalysisException: [FAILED_JDBC.UNCLASSIFIED] Failed JDBC jdbc: on the operation: Failed to connect SQLSTATE: HV000
